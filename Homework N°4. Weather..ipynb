# %% [markdown]
# # WeatherAPI (Weather)
#
# Answer the following questions using [WeatherAPI](http://www.weatherapi.com/). I've added three cells for most questions but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# Be sure to take advantage of both the documentation and the API Explorer!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*
# - *Tip: Remember you only need to import requests once!*

# %%
from dotenv import load_dotenv
import os
load_dotenv()
api_key = os.getenv("api_key")
import requests
url = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q=Buenos Aires&aqi=no"
response = requests.get(url)
data = response.json()
print(data)
# Out:
# {'location': {'name': 'Buenos Aires', 'region': 'Distrito Federal', 'country': 'Argentina', 'lat': -34.59, 'lon': -58.67, 'tz_id': 'America/Argentina/Buenos_Aires', 'localtime_epoch': 1686762450, 'localtime': '2023-06-14 14:07'}, 'current': {'last_updated_epoch': 1686762000, 'last_updated': '2023-06-14 14:00', 'temp_c': 14.0, 'temp_f': 57.2, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 6.9, 'wind_kph': 11.2, 'wind_degree': 350, 'wind_dir': 'N', 'pressure_mb': 1029.0, 'pressure_in': 30.39, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 44, 'cloud': 0, 'feelslike_c': 13.7, 'feelslike_f': 56.7, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 5.0, 'gust_mph': 5.6, 'gust_kph': 9.0}}

# %% [markdown]
# ## 1) Make a request to the Weather API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
url = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q=Buenos Aires&aqi=no"
response = requests.get(url)
data = response.json()
print(data["location"]["country"])
print("")
# Out:
# Argentina

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
url = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q=Buenos Aires&aqi=no"
response = requests.get(url)
data = response.json()
print("The current wind speed is", data["current"]["wind_kph"], "kph.")
# Out:
# The current wind speed is 3.6 kph.

# %%
url = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q=Buenos Aires&aqi=no"
response = requests.get(url)
data = response.json()
print("")
if data["current"]["temp_c"] > data["current"]["feelslike_c"]:
  colder = data["current"]["temp_c"] - data["current"]["feelslike_c"]
  print("It feels", round(colder, 2), "degrees colder")
elif data["current"]["temp_c"] < data["current"]["feelslike_c"]:
  warmer = data["current"]["temp_c"] - data["current"]["feelslike_c"]
  print("It feels", round(warmer, 2), "degrees colder")
else:
  print("It feels like the temperature.")
# Out:
# It feels 1.0 degrees colder

# %% [markdown]
# ## 3) What is the API endpoint for moon-related information? For the place you decided on above, how much of the moon will be visible tomorrow?
#
# - *Tip: Check the documentation!*
# - *Tip: If you aren't sure what something means, ask in Slack*

# %%
url = f"http://api.weatherapi.com/v1/astronomy.json?key={api_key}&q=Buenos Aires&dt=2023-06-14"
response = requests.get(url)
data = response.json()
print(data["astronomy"]["astro"]["moon_phase"])
# Out:
# Waning Crescent

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?
#
# - *Tip: When you requested moon data, you probably overwrote your variables! If so, you'll need to make a new request.*

# %%
url = f"http://api.weatherapi.com/v1/forecast.json?key={api_key}&q=Buenos Aires&days=1&aqi=no&alerts=no"
response = requests.get(url)
data = response.json()

# %%
forecast = data["forecast"]["forecastday"]
for item in forecast:
  maxtemp = item["day"]["maxtemp_c"]
  mintemp = item["day"]["mintemp_c"]
  dif = maxtemp - mintemp 
  print("The difference between high and low temperatures for today:", dif)
# Out:
# The difference between high and low temperatures for today: 9.7

# %%
# Another way
forecast = data["forecast"]["forecastday"]
for item in forecast:
    print(item["day"]["maxtemp_c"] - item["day"]["mintemp_c"])
# Out:
# 9.7

# %%
# Another way
for temp_dif in data["forecast"]["forecastday"]:
  dif = temp_dif["day"]["maxtemp_c"] - temp_dif["day"]["mintemp_c"]
  print(dif)
# Out:
# 9.7

# %% [markdown]
# ## 4.5) How can you avoid the "oh no I don't have the data any more because I made another request" problem in the future?
#
# What variable(s) do you have to rename, and what would you rename them?

# %%
# I try to rename variables using specific words of the task; for example: _forecast, _temp, etcétera.

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next three days' worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
url = "http://api.weatherapi.com/v1/forecast.json?key={api_key}&q=Buenos Aires&days=3&aqi=no&alerts=no"
response = requests.get(url)
data = response.json()

# %%
for max_temp in data["forecast"]["forecastday"]:
  print(max_temp["date"])
  if max_temp["day"]["maxtemp_c"] > 30:
    print("The temperature will be", max_temp["day"]["maxtemp_c"], "It will be hot.")
  elif max_temp["day"]["maxtemp_c"] < 15:
    print("The temperature will be", max_temp["day"]["maxtemp_c"], "It will be cold.")
  else:
    print("The temperature will be", max_temp["day"]["maxtemp_c"], "It will be warm.")
# Out:
# 2023-06-13
# The temperature will be 14.7 It will be cold.
# 2023-06-14
# The temperature will be 16.1 It will be warm.
# 2023-06-15
# The temperature will be 15.1 It will be warm.

# %% [markdown]
# ## 5b) The question above used to be an entire week, but not any more. Try to re-use the code above to print out seven days.
#
# What happens? Can you figure out why it doesn't work?
#
# * *Tip: it has to do with the reason you're using an API key - maybe take a look at the "Air Quality Data" introduction for a hint? If you can't figure it out right now, no worries.*

# %%
url = f"http://api.weatherapi.com/v1/forecast.json?key={api_key}&q=Buenos Aires&days=7&aqi=no&alerts=no"
response = requests.get(url)
data = response.json()

# %%
for max_temp in data["forecast"]["forecastday"]:
  print(max_temp["date"])
  if max_temp["day"]["maxtemp_c"] > 30:
    print("The temperature will be", max_temp["day"]["maxtemp_c"], "It will be hot.")
  elif max_temp["day"]["maxtemp_c"] < 15:
    print("The temperature will be", max_temp["day"]["maxtemp_c"], "It will be cold.")
  else:
    print("The temperature will be", max_temp["day"]["maxtemp_c"], "It will be warm.")
# Out:
# 2023-06-13
# The temperature will be 14.7 It will be cold.
# 2023-06-14
# The temperature will be 16.1 It will be warm.
# 2023-06-15
# The temperature will be 15.1 It will be warm.
# 2023-06-16
# The temperature will be 17.7 It will be warm.
# 2023-06-17
# The temperature will be 16.6 It will be warm.
# 2023-06-18
# The temperature will be 17.2 It will be warm.
# 2023-06-19
# The temperature will be 18.4 It will be warm.

# %% [markdown]
# ## 6) What will be the hottest day in the next three days? What is the high temperature on that day?

# %%
url = f"http://api.weatherapi.com/v1/forecast.json?key={api_key}&q=Buenos Aires&days=3&aqi=no&alerts=no"
response = requests.get(url)
data = response.json()

# %%
for max_temp in data["forecast"]["forecastday"]:
  print(max_temp["date"])
  if max_temp["day"]["maxtemp_c"] > 30:
    print("The temperature will be", max_temp["day"]["maxtemp_c"], "It will be hot.")
  elif max_temp["day"]["maxtemp_c"] < 15:
    print("The temperature will be", max_temp["day"]["maxtemp_c"], "It will be cold.")
  else:
    print("The temperature will be", max_temp["day"]["maxtemp_c"], "It will be warm.")
# Out:
# 2023-06-13
# The temperature will be 14.7 It will be cold.
# 2023-06-14
# The temperature will be 16.1 It will be warm.
# 2023-06-15
# The temperature will be 15.1 It will be warm.

# %%
maxtemp_list = []
for item in data["forecast"]["forecastday"]:
    maxtemp = item["day"]["maxtemp_c"]
    maxtemp_list.append(maxtemp)
print(max(maxtemp_list))
# Out:
# 16.1

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
# - *Tip: You'll only need one day of forecast*

# %%
url = f"http://api.weatherapi.com/v1/forecast.json?key={api_key}&q=Miami, Florida&days=1&aqi=no&alerts=no"
response = requests.get(url)
data = response.json()

# %%
item1 = data["forecast"]["forecastday"]
print(item1)
# Out:
# [{'date': '2023-06-14', 'date_epoch': 1686700800, 'day': {'maxtemp_c': 34.1, 'maxtemp_f': 93.4, 'mintemp_c': 28.1, 'mintemp_f': 82.6, 'avgtemp_c': 30.1, 'avgtemp_f': 86.1, 'maxwind_mph': 16.6, 'maxwind_kph': 26.6, 'totalprecip_mm': 9.5, 'totalprecip_in': 0.37, 'totalsnow_cm': 0.0, 'avgvis_km': 9.7, 'avgvis_miles': 6.0, 'avghumidity': 69.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': 89, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Moderate rain', 'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png', 'code': 1189}, 'uv': 7.0}, 'astro': {'sunrise': '06:29 AM', 'sunset': '08:13 PM', 'moonrise': '03:43 AM', 'moonset': '05:10 PM', 'moon_phase': 'Waning Crescent', 'moon_illumination': '18', 'is_moon_up': 0, 'is_sun_up': 1}, 'hour': [{'time_epoch': 1686715200, 'time': '2023-06-14 00:00', 'temp_c': 28.5, 'temp_f': 83.3, 'is_day': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png', 'code': 1063}, 'wind_mph': 7.2, 'wind_kph': 11.5, 'wind_degree': 204, 'wind_dir': 'SSW', 'pressure_mb': 1016.0, 'pressure_in': 29.99, 'precip_mm': 1.1, 'precip_in': 0.04, 'humidity': 73, 'cloud': 87, 'feelslike_c': 32.3, 'feelslike_f': 90.1, 'windchill_c': 28.5, 'windchill_f': 83.3, 'heatindex_c': 32.3, 'heatindex_f': 90.1, 'dewpoint_c': 23.3, 'dewpoint_f': 73.9, 'will_it_rain': 1, 'chance_of_rain': 74, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 9.0, 'vis_miles': 5.0, 'gust_mph': 12.5, 'gust_kph': 20.2, 'uv': 1.0}, {'time_epoch': 1686718800, 'time': '2023-06-14 01:00', 'temp_c': 28.5, 'temp_f': 83.3, 'is_day': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png', 'code': 1063}, 'wind_mph': 5.8, 'wind_kph': 9.4, 'wind_degree': 216, 'wind_dir': 'SW', 'pressure_mb': 1015.0, 'pressure_in': 29.98, 'precip_mm': 0.9, 'precip_in': 0.04, 'humidity': 74, 'cloud': 71, 'feelslike_c': 32.4, 'feelslike_f': 90.3, 'windchill_c': 28.5, 'windchill_f': 83.3, 'heatindex_c': 32.4, 'heatindex_f': 90.3, 'dewpoint_c': 23.4, 'dewpoint_f': 74.1, 'will_it_rain': 1, 'chance_of_rain': 73, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 9.0, 'vis_miles': 5.0, 'gust_mph': 10.5, 'gust_kph': 16.9, 'uv': 1.0}, {'time_epoch': 1686722400, 'time': '2023-06-14 02:00', 'temp_c': 28.1, 'temp_f': 82.6, 'is_day': 0, 'condition': {'text': 'Moderate or heavy rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/356.png', 'code': 1243}, 'wind_mph': 6.0, 'wind_kph': 9.7, 'wind_degree': 218, 'wind_dir': 'SW', 'pressure_mb': 1015.0, 'pressure_in': 29.97, 'precip_mm': 5.5, 'precip_in': 0.22, 'humidity': 75, 'cloud': 83, 'feelslike_c': 31.8, 'feelslike_f': 89.2, 'windchill_c': 28.1, 'windchill_f': 82.6, 'heatindex_c': 31.8, 'heatindex_f': 89.2, 'dewpoint_c': 23.2, 'dewpoint_f': 73.8, 'will_it_rain': 1, 'chance_of_rain': 87, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 7.0, 'vis_miles': 4.0, 'gust_mph': 11.4, 'gust_kph': 18.4, 'uv': 1.0}, {'time_epoch': 1686726000, 'time': '2023-06-14 03:00', 'temp_c': 28.3, 'temp_f': 82.9, 'is_day': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png', 'code': 1063}, 'wind_mph': 6.3, 'wind_kph': 10.1, 'wind_degree': 213, 'wind_dir': 'SSW', 'pressure_mb': 1014.0, 'pressure_in': 29.95, 'precip_mm': 0.2, 'precip_in': 0.01, 'humidity': 75, 'cloud': 76, 'feelslike_c': 32.1, 'feelslike_f': 89.8, 'windchill_c': 28.3, 'windchill_f': 82.9, 'heatindex_c': 32.1, 'heatindex_f': 89.8, 'dewpoint_c': 23.4, 'dewpoint_f': 74.1, 'will_it_rain': 0, 'chance_of_rain': 65, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 8.7, 'gust_kph': 14.0, 'uv': 1.0}, {'time_epoch': 1686729600, 'time': '2023-06-14 04:00', 'temp_c': 28.2, 'temp_f': 82.8, 'is_day': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png', 'code': 1063}, 'wind_mph': 6.3, 'wind_kph': 10.1, 'wind_degree': 206, 'wind_d ...

# %%
import json
pretty = json.dumps(item1, indent = 4)
print(pretty)
# Out:
# [
#     {
#         "date": "2023-06-14",
#         "date_epoch": 1686700800,
#         "day": {
#             "maxtemp_c": 34.1,
#             "maxtemp_f": 93.4,
#             "mintemp_c": 28.1,
#             "mintemp_f": 82.6,
#             "avgtemp_c": 30.1,
#             "avgtemp_f": 86.1,
#             "maxwind_mph": 16.6,
#             "maxwind_kph": 26.6,
#             "totalprecip_mm": 9.5,
#             "totalprecip_in": 0.37,
#             "totalsnow_cm": 0.0,
#             "avgvis_km": 9.7,
#             "avgvis_miles": 6.0,
#             "avghumidity": 69.0,
#             "daily_will_it_rain": 1,
#             "daily_chance_of_rain": 89,
#             "daily_will_it_snow": 0,
#             "daily_chance_of_snow": 0,
#             "condition": {
#                 "text": "Moderate rain",
#                 "icon": "//cdn.weatherapi.com/weather/64x64/day/302.png",
#                 "code": 1189
#             },
#             "uv": 7.0
#         },
#         "astro": {
#             "sunrise": "06:29 AM",
#             "sunset": "08:13 PM",
#             "moonrise": "03:43 AM",
#             "moonset": "05:10 PM",
#             "moon_phase": "Waning Crescent",
#             "moon_illumination": "18",
#             "is_moon_up": 0,
#             "is_sun_up": 1
#         },
#         "hour": [
#             {
#                 "time_epoch": 1686715200,
#                 "time": "2023-06-14 00:00",
#                 "temp_c": 28.5,
#                 "temp_f": 83.3,
#                 "is_day": 0,
#                 "condition": {
#                     "text": "Patchy rain possible",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/night/176.png",
#                     "code": 1063
#                 },
#                 "wind_mph": 7.2,
#                 "wind_kph": 11.5,
#                 "wind_degree": 204,
#                 "wind_dir": "SSW",
#                 "pressure_mb": 1016.0,
#                 "pressure_in": 29.99,
#                 "precip_mm": 1.1,
#                 "precip_in": 0.04,
#                 "humidity": 73,
#                 "cloud": 87,
#                 "feelslike_c": 32.3,
#                 "feelslike_f": 90.1,
#                 "windchill_c": 28.5,
#                 "windchill_f": 83.3,
#                 "heatindex_c": 32.3,
#                 "heatindex_f": 90.1,
#                 "dewpoint_c": 23.3,
#                 "dewpoint_f": 73.9,
#                 "will_it_rain": 1,
#                 "chance_of_rain": 74,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 9.0,
#                 "vis_miles": 5.0,
#                 "gust_mph": 12.5,
#                 "gust_kph": 20.2,
#                 "uv": 1.0
#             },
#             {
#                 "time_epoch": 1686718800,
#                 "time": "2023-06-14 01:00",
#                 "temp_c": 28.5,
#                 "temp_f": 83.3,
#                 "is_day": 0,
#                 "condition": {
#                     "text": "Patchy rain possible",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/night/176.png",
#                     "code": 1063
#                 },
#                 "wind_mph": 5.8,
#                 "wind_kph": 9.4,
#                 "wind_degree": 216,
#                 "wind_dir": "SW",
#                 "pressure_mb": 1015.0,
#                 "pressure_in": 29.98,
#                 "precip_mm": 0.9,
#                 "precip_in": 0.04,
#                 "humidity": 74,
#                 "cloud": 71,
#                 "feelslike_c": 32.4,
#                 "feelslike_f": 90.3,
#                 "windchill_c": 28.5,
#                 "windchill_f": 83.3,
#                 "heatindex_c": 32.4,
#                 "heatindex_f": 90.3,
#                 "dewpoint_c": 23.4,
#                 "dewpoint_f": 74.1,
#                 "will_it_rain": 1,
#                 "chance_of_rain": 73,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 9.0,
#                 "vis_miles": 5.0,
#                 "gust_mph": 10.5,
#                 "gust_kph": 16.9,
#                 "uv": 1.0
#             },
#             {
#                 "time_epoch": 1686722400,
#                 "time": "2023-06-14 02:00",
#                 "temp_c": 28.1,
#                 "temp_f": 82.6,
#                 "is_day": 0,
#                 "condition": {
#                     "text": "Moderate or heavy rain shower",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/night/356.png",
#                     "code": 1243
#                 },
#                 "wind_mph": 6.0,
#                 "wind_kph": 9.7,
#                 "wind_degree": 218,
#                 "wind_dir": "SW",
#                 "pressure_mb": 1015.0,
#                 "pressure_in": 29.97,
#                 "precip_mm": 5.5,
#                 "precip_in": 0.22,
#                 "humidity": 75,
#                 "cloud": 83,
#                 "feelslike_c": 31.8,
#                 "feelslike_f": 89.2,
#                 "windchill_c": 28.1,
#                 "windchill_f": 82.6,
#                 "heatindex_c": 31.8,
#                 "heatindex_f": 89.2,
#                 "dewpoint_c": 23.2,
#                 "dewpoint_f": 73.8,
#                 "will_it_rain": 1,
#                 "chance_of_rain": 87,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 7.0,
#                 "vis_miles": 4.0,
#                 "gust_mph": 11.4,
#                 "gust_kph": 18.4,
#                 "uv": 1.0
#             },
#             {
#                 "time_epoch": 1686726000,
#                 "time": "2023-06-14 03:00",
#                 "temp_c": 28.3,
#                 "temp_f": 82.9,
#                 "is_day": 0,
#                 "condition": {
#                     "text": "Patchy rain possible",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/night/176.png",
#                     "code": 1063
#                 },
#                 "wind_mph": 6.3,
#                 "wind_kph": 10.1,
#                 "wind_degree": 213,
#                 "wind_dir": "SSW",
#                 "pressure_mb": 1014.0,
#                 "pressure_in": 29.95,
#                 "precip_mm": 0.2,
#                 "precip_in": 0.01,
#                 "humidity": 75,
#                 "cloud": 76,
#                 "feelslike_c": 32.1,
#                 "feelslike_f": 89.8,
#                 "windchill_c": 28.3,
#                 "windchill_f": 82.9,
#                 "heatindex_c": 32.1,
#                 "heatindex_f": 89.8,
#                 "dewpoint_c": 23.4,
#                 "dewpoint_f": 74.1,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 65,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 8.7,
#                 "gust_kph": 14.0,
#                 "uv": 1.0
#             },
#             {
#                 "time_epoch": 1686729600,
#                 "time": "2023-06-14 04:00",
#                 "temp_c": 28.2,
#                 "temp_f": 82.8,
#                 "is_day": 0,
#                 "condition": {
#                     "text": "Patchy rain possible",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/night/176.png",
#                     "code": 1063
#                 },
#                 "wind_mph": 6.3,
#                 "wind_kph": 10.1,
#                 "wind_degree": 206,
#                 "wind_dir": "SSW",
#                 "pressure_mb": 1014.0,
#                 "pressure_in": 29.94,
#                 "precip_mm": 0.1,
#                 "precip_in": 0.0,
#                 "humidity": 75,
#                 "cloud": 85,
#                 "feelslike_c": 32.0,
#                 "feelslike_f": 89.6,
#                 "windchill_c": 28.2,
#                 "windchill_f": 82.8,
#                 "heatindex_c": 32.0,
#                 "heatindex_f": 89.6,
#                 "dewpoint_c": 23.4,
#                 "dewpoint_f": 74.1,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 65,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 8.7,
#                 "gust_kph": 14.0,
#                 "uv": 1.0
#             },
#             {
#                 "time_epoch": 1686733200,
#                 "time": "2023-06-14 05:00",
#                 "temp_c": 28.1,
#                 "temp_f": 82.6,
#                 "is_day": 0,
#                 "condition": {
#                     "text": "Patchy rain possible",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/night/176.png",
#                     "code": 1063
#                 },
#                 "wind_mph": 6.3,
#                 "wind_kph": 10.1,
#                 "wind_degree": 198,
#                 "wind_dir": "SSW",
#                 "pressure_mb": 1014.0,
#                 "pressure_in": 29.93,
#                 "precip_mm": 0.2,
#                 "precip_in": 0.01,
#                 "humidity": 76,
#                 "cloud": 84,
#                 "feelslike_c": 31.9,
#                 "feelslike_f": 89.4,
#                 "windchill_c": 28.1,
#                 "windchill_f": 82.6,
#                 "heatindex_c": 31.9,
#                 "heatindex_f": 89.4,
#                 "dewpoint_c": 23.4,
#                 "dewpoint_f": 74.1,
#                 "will_it_rain": 1,
#                 "chance_of_rain": 79,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 8.7,
#                 "gust_kph": 14.0,
#                 "uv": 1.0
#             },
#             {
#                 "time_epoch": 1686736800,
#                 "time": "2023-06-14 06:00",
#                 "temp_c": 28.1,
#                 "temp_f": 82.6,
#                 "is_day": 0,
#                 "condition": {
#                     "text": "Clear",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/night/113.png",
#                     "code": 1000
#                 },
#                 "wind_mph": 7.2,
#                 "wind_kph": 11.5,
#                 "wind_degree": 186,
#                 "wind_dir": "S",
#                 "pressure_mb": 1014.0,
#                 "pressure_in": 29.94,
#                 "precip_mm": 0.0,
#                 "precip_in": 0.0,
#                 "humidity": 76,
#                 "cloud": 8,
#                 "feelslike_c": 31.8,
#                 "feelslike_f": 89.2,
#                 "windchill_c": 28.1,
#                 "windchill_f": 82.6,
#                 "heatindex_c": 31.8,
#                 "heatindex_f": 89.2,
#                 "dewpoint_c": 23.4,
#                 "dewpoint_f": 74.1,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 0,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 9.8,
#                 "gust_kph": 15.8,
#                 "uv": 1.0
#             },
#             {
#                 "time_epoch": 1686740400,
#                 "time": "2023-06-14 07:00",
#                 "temp_c": 28.3,
#                 "temp_f": 82.9,
#                 "is_day": 1,
#                 "condition": {
#                     "text": "Sunny",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#                     "code": 1000
#                 },
#                 "wind_mph": 9.8,
#                 "wind_kph": 15.8,
#                 "wind_degree": 176,
#                 "wind_dir": "S",
#                 "pressure_mb": 1014.0,
#                 "pressure_in": 29.94,
#                 "precip_mm": 0.0,
#                 "precip_in": 0.0,
#                 "humidity": 75,
#                 "cloud": 12,
#                 "feelslike_c": 32.1,
#                 "feelslike_f": 89.8,
#                 "windchill_c": 28.3,
#                 "windchill_f": 82.9,
#                 "heatindex_c": 32.1,
#                 "heatindex_f": 89.8,
#                 "dewpoint_c": 23.3,
#                 "dewpoint_f": 73.9,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 0,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 13.6,
#                 "gust_kph": 22.0,
#                 "uv": 7.0
#             },
#             {
#                 "time_epoch": 1686744000,
#                 "time": "2023-06-14 08:00",
#                 "temp_c": 28.7,
#                 "temp_f": 83.7,
#                 "is_day": 1,
#                 "condition": {
#                     "text": "Patchy rain possible",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/day/176.png",
#                     "code": 1063
#                 },
#                 "wind_mph": 12.3,
#                 "wind_kph": 19.8,
#                 "wind_degree": 173,
#                 "wind_dir": "S",
#                 "pressure_mb": 1014.0,
#                 "pressure_in": 29.95,
#                 "precip_mm": 0.2,
#                 "precip_in": 0.01,
#                 "humidity": 72,
#                 "cloud": 72,
#                 "feelslike_c": 32.5,
#                 "feelslike_f": 90.5,
#                 "windchill_c": 28.7,
#                 "windchill_f": 83.7,
#                 "heatindex_c": 32.5,
#                 "heatindex_f": 90.5,
#                 "dewpoint_c": 23.2,
#                 "dewpoint_f": 73.8,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 68,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 9.0,
#                 "vis_miles": 5.0,
#                 "gust_mph": 16.3,
#                 "gust_kph": 26.3,
#                 "uv": 6.0
#             },
#             {
#                 "time_epoch": 1686747600,
#                 "time": "2023-06-14 09:00",
#                 "temp_c": 29.2,
#                 "temp_f": 84.6,
#                 "is_day": 1,
#                 "condition": {
#                     "text": "Partly cloudy",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/day/116.png",
#                     "code": 1003
#                 },
#                 "wind_mph": 14.1,
#                 "wind_kph": 22.7,
#                 "wind_degree": 168,
#                 "wind_dir": "SSE",
#                 "pressure_mb": 1015.0,
#                 "pressure_in": 29.96,
#                 "precip_mm": 0.0,
#                 "precip_in": 0.0,
#                 "humidity": 71,
#                 "cloud": 31,
#                 "feelslike_c": 33.4,
#                 "feelslike_f": 92.1,
#                 "windchill_c": 29.2,
#                 "windchill_f": 84.6,
#                 "heatindex_c": 33.4,
#                 "heatindex_f": 92.1,
#                 "dewpoint_c": 23.4,
#                 "dewpoint_f": 74.1,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 0,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 17.4,
#                 "gust_kph": 28.1,
#                 "uv": 7.0
#             },
#             {
#                 "time_epoch": 1686751200,
#                 "time": "2023-06-14 10:00",
#                 "temp_c": 29.6,
#                 "temp_f": 85.3,
#                 "is_day": 1,
#                 "condition": {
#                     "text": "Sunny",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#                     "code": 1000
#                 },
#                 "wind_mph": 13.2,
#                 "wind_kph": 21.2,
#                 "wind_degree": 166,
#                 "wind_dir": "SSE",
#                 "pressure_mb": 1015.0,
#                 "pressure_in": 29.97,
#                 "precip_mm": 0.0,
#                 "precip_in": 0.0,
#                 "humidity": 69,
#                 "cloud": 24,
#                 "feelslike_c": 34.0,
#                 "feelslike_f": 93.2,
#                 "windchill_c": 29.6,
#                 "windchill_f": 85.3,
#                 "heatindex_c": 34.0,
#                 "heatindex_f": 93.2,
#                 "dewpoint_c": 23.4,
#                 "dewpoint_f": 74.1,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 0,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 15.7,
#                 "gust_kph": 25.2,
#                 "uv": 7.0
#             },
#             {
#                 "time_epoch": 1686754800,
#                 "time": "2023-06-14 11:00",
#                 "temp_c": 30.3,
#                 "temp_f": 86.5,
#                 "is_day": 1,
#                 "condition": {
#                     "text": "Sunny",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#                     "code": 1000
#                 },
#                 "wind_mph": 10.3,
#                 "wind_kph": 16.6,
#                 "wind_degree": 167,
#                 "wind_dir": "SSE",
#                 "pressure_mb": 1016.0,
#                 "pressure_in": 29.99,
#                 "precip_mm": 0.0,
#                 "precip_in": 0.0,
#                 "humidity": 66,
#                 "cloud": 25,
#                 "feelslike_c": 34.9,
#                 "feelslike_f": 94.8,
#                 "windchill_c": 30.3,
#                 "windchill_f": 86.5,
#                 "heatindex_c": 34.9,
#                 "heatindex_f": 94.8,
#                 "dewpoint_c": 23.3,
#                 "dewpoint_f": 73.9,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 0,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 11.9,
#                 "gust_kph": 19.1,
#                 "uv": 8.0
#             },
#             {
#                 "time_epoch": 1686758400,
#                 "time": "2023-06-14 12:00",
#                 "temp_c": 31.2,
#                 "temp_f": 88.2,
#                 "is_day": 1,
#                 "condition": {
#                     "text": "Sunny",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#                     "code": 1000
#                 },
#                 "wind_mph": 10.5,
#                 "wind_kph": 16.9,
#                 "wind_degree": 156,
#                 "wind_dir": "SSE",
#                 "pressure_mb": 1016.0,
#                 "pressure_in": 29.99,
#                 "precip_mm": 0.0,
#                 "precip_in": 0.0,
#                 "humidity": 64,
#                 "cloud": 13,
#                 "feelslike_c": 36.4,
#                 "feelslike_f": 97.5,
#                 "windchill_c": 31.2,
#                 "windchill_f": 88.2,
#                 "heatindex_c": 36.4,
#                 "heatindex_f": 97.5,
#                 "dewpoint_c": 23.6,
#                 "dewpoint_f": 74.5,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 0,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 12.1,
#                 "gust_kph": 19.4,
#                 "uv": 8.0
#             },
#             {
#                 "time_epoch": 1686762000,
#                 "time": "2023-06-14 13:00",
#                 "temp_c": 33.7,
#                 "temp_f": 92.7,
#                 "is_day": 1,
#                 "condition": {
#                     "text": "Sunny",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#                     "code": 1000
#                 },
#                 "wind_mph": 12.1,
#                 "wind_kph": 19.4,
#                 "wind_degree": 151,
#                 "wind_dir": "SSE",
#                 "pressure_mb": 1015.0,
#                 "pressure_in": 29.98,
#                 "precip_mm": 0.0,
#                 "precip_in": 0.0,
#                 "humidity": 63,
#                 "cloud": 7,
#                 "feelslike_c": 42.6,
#                 "feelslike_f": 108.7,
#                 "windchill_c": 33.7,
#                 "windchill_f": 92.7,
#                 "heatindex_c": 42.6,
#                 "heatindex_f": 108.7,
#                 "dewpoint_c": 25.8,
#                 "dewpoint_f": 78.4,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 0,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 13.9,
#                 "gust_kph": 22.3,
#                 "uv": 8.0
#             },
#             {
#                 "time_epoch": 1686765600,
#                 "time": "2023-06-14 14:00",
#                 "temp_c": 33.9,
#                 "temp_f": 93.0,
#                 "is_day": 1,
#                 "condition": {
#                     "text": "Sunny",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#                     "code": 1000
#                 },
#                 "wind_mph": 13.2,
#                 "wind_kph": 21.2,
#                 "wind_degree": 153,
#                 "wind_dir": "SSE",
#                 "pressure_mb": 1015.0,
#                 "pressure_in": 29.97,
#                 "precip_mm": 0.0,
#                 "precip_in": 0.0,
#                 "humidity": 63,
#                 "cloud": 6,
#                 "feelslike_c": 43.0,
#                 "feelslike_f": 109.4,
#                 "windchill_c": 33.9,
#                 "windchill_f": 93.0,
#                 "heatindex_c": 43.0,
#                 "heatindex_f": 109.4,
#                 "dewpoint_c": 25.8,
#                 "dewpoint_f": 78.4,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 0,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 15.2,
#                 "gust_kph": 24.5,
#                 "uv": 8.0
#             },
#             {
#                 "time_epoch": 1686769200,
#                 "time": "2023-06-14 15:00",
#                 "temp_c": 34.1,
#                 "temp_f": 93.4,
#                 "is_day": 1,
#                 "condition": {
#                     "text": "Sunny",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#                     "code": 1000
#                 },
#                 "wind_mph": 13.2,
#                 "wind_kph": 21.2,
#                 "wind_degree": 155,
#                 "wind_dir": "SSE",
#                 "pressure_mb": 1015.0,
#                 "pressure_in": 29.96,
#                 "precip_mm": 0.0,
#                 "precip_in": 0.0,
#                 "humidity": 62,
#                 "cloud": 5,
#                 "feelslike_c": 43.2,
#                 "feelslike_f": 109.8,
#                 "windchill_c": 34.1,
#                 "windchill_f": 93.4,
#                 "heatindex_c": 43.2,
#                 "heatindex_f": 109.8,
#                 "dewpoint_c": 25.8,
#                 "dewpoint_f": 78.4,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 0,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 15.2,
#                 "gust_kph": 24.5,
#                 "uv": 8.0
#             },
#             {
#                 "time_epoch": 1686772800,
#                 "time": "2023-06-14 16:00",
#                 "temp_c": 34.0,
#                 "temp_f": 93.2,
#                 "is_day": 1,
#                 "condition": {
#                     "text": "Sunny",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#                     "code": 1000
#                 },
#                 "wind_mph": 13.9,
#                 "wind_kph": 22.3,
#                 "wind_degree": 156,
#                 "wind_dir": "SSE",
#                 "pressure_mb": 1014.0,
#                 "pressure_in": 29.95,
#                 "precip_mm": 0.0,
#                 "precip_in": 0.0,
#                 "humidity": 62,
#                 "cloud": 5,
#                 "feelslike_c": 42.9,
#                 "feelslike_f": 109.2,
#                 "windchill_c": 34.0,
#                 "windchill_f": 93.2,
#                 "heatindex_c": 42.9,
#                 "heatindex_f": 109.2,
#                 "dewpoint_c": 25.6,
#                 "dewpoint_f": 78.1,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 0,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 15.9,
#                 "gust_kph": 25.6,
#                 "uv": 8.0
#             },
#             {
#                 "time_epoch": 1686776400,
#                 "time": "2023-06-14 17:00",
#                 "temp_c": 33.4,
#                 "temp_f": 92.1,
#                 "is_day": 1,
#                 "condition": {
#                     "text": "Sunny",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#                     "code": 1000
#                 },
#                 "wind_mph": 16.6,
#                 "wind_kph": 26.6,
#                 "wind_degree": 155,
#                 "wind_dir": "SSE",
#                 "pressure_mb": 1013.0,
#                 "pressure_in": 29.92,
#                 "precip_mm": 0.0,
#                 "precip_in": 0.0,
#                 "humidity": 63,
#                 "cloud": 4,
#                 "feelslike_c": 41.5,
#                 "feelslike_f": 106.7,
#                 "windchill_c": 33.4,
#                 "windchill_f": 92.1,
#                 "heatindex_c": 41.5,
#                 "heatindex_f": 106.7,
#                 "dewpoint_c": 25.3,
#                 "dewpoint_f": 77.5,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 0,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 19.0,
#                 "gust_kph": 30.6,
#                 "uv": 8.0
#             },
#             {
#                 "time_epoch": 1686780000,
#                 "time": "2023-06-14 18:00",
#                 "temp_c": 32.3,
#                 "temp_f": 90.1,
#                 "is_day": 1,
#                 "condition": {
#                     "text": "Sunny",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#                     "code": 1000
#                 },
#                 "wind_mph": 13.6,
#                 "wind_kph": 22.0,
#                 "wind_degree": 165,
#                 "wind_dir": "SSE",
#                 "pressure_mb": 1014.0,
#                 "pressure_in": 29.94,
#                 "precip_mm": 0.0,
#                 "precip_in": 0.0,
#                 "humidity": 64,
#                 "cloud": 4,
#                 "feelslike_c": 39.0,
#                 "feelslike_f": 102.2,
#                 "windchill_c": 32.3,
#                 "windchill_f": 90.1,
#                 "heatindex_c": 39.0,
#                 "heatindex_f": 102.2,
#                 "dewpoint_c": 24.6,
#                 "dewpoint_f": 76.3,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 0,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 15.7,
#                 "gust_kph": 25.2,
#                 "uv": 8.0
#             },
#             {
#                 "time_epoch": 1686783600,
#                 "time": "2023-06-14 19:00",
#                 "temp_c": 30.0,
#                 "temp_f": 86.0,
#                 "is_day": 1,
#                 "condition": {
#                     "text": "Patchy rain possible",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/day/176.png",
#                     "code": 1063
#                 },
#                 "wind_mph": 3.4,
#                 "wind_kph": 5.4,
#                 "wind_degree": 214,
#                 "wind_dir": "SW",
#                 "pressure_mb": 1015.0,
#                 "pressure_in": 29.97,
#                 "precip_mm": 0.2,
#                 "precip_in": 0.01,
#                 "humidity": 68,
#                 "cloud": 77,
#                 "feelslike_c": 34.6,
#                 "feelslike_f": 94.3,
#                 "windchill_c": 30.0,
#                 "windchill_f": 86.0,
#                 "heatindex_c": 34.6,
#                 "heatindex_f": 94.3,
#                 "dewpoint_c": 23.5,
#                 "dewpoint_f": 74.3,
#                 "will_it_rain": 1,
#                 "chance_of_rain": 89,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 4.5,
#                 "gust_kph": 7.2,
#                 "uv": 7.0
#             },
#             {
#                 "time_epoch": 1686787200,
#                 "time": "2023-06-14 20:00",
#                 "temp_c": 28.9,
#                 "temp_f": 84.0,
#                 "is_day": 1,
#                 "condition": {
#                     "text": "Patchy rain possible",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/day/176.png",
#                     "code": 1063
#                 },
#                 "wind_mph": 0.2,
#                 "wind_kph": 0.4,
#                 "wind_degree": 208,
#                 "wind_dir": "SSW",
#                 "pressure_mb": 1015.0,
#                 "pressure_in": 29.97,
#                 "precip_mm": 1.1,
#                 "precip_in": 0.04,
#                 "humidity": 68,
#                 "cloud": 80,
#                 "feelslike_c": 32.3,
#                 "feelslike_f": 90.1,
#                 "windchill_c": 28.9,
#                 "windchill_f": 84.0,
#                 "heatindex_c": 32.3,
#                 "heatindex_f": 90.1,
#                 "dewpoint_c": 22.4,
#                 "dewpoint_f": 72.3,
#                 "will_it_rain": 1,
#                 "chance_of_rain": 83,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 9.0,
#                 "vis_miles": 5.0,
#                 "gust_mph": 0.2,
#                 "gust_kph": 0.4,
#                 "uv": 6.0
#             },
#             {
#                 "time_epoch": 1686790800,
#                 "time": "2023-06-14 21:00",
#                 "temp_c": 28.8,
#                 "temp_f": 83.8,
#                 "is_day": 0,
#                 "condition": {
#                     "text": "Clear",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/night/113.png",
#                     "code": 1000
#                 },
#                 "wind_mph": 5.6,
#                 "wind_kph": 9.0,
#                 "wind_degree": 93,
#                 "wind_dir": "E",
#                 "pressure_mb": 1015.0,
#                 "pressure_in": 29.98,
#                 "precip_mm": 0.0,
#                 "precip_in": 0.0,
#                 "humidity": 69,
#                 "cloud": 21,
#                 "feelslike_c": 32.3,
#                 "feelslike_f": 90.1,
#                 "windchill_c": 28.8,
#                 "windchill_f": 83.8,
#                 "heatindex_c": 32.3,
#                 "heatindex_f": 90.1,
#                 "dewpoint_c": 22.6,
#                 "dewpoint_f": 72.7,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 0,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 7.2,
#                 "gust_kph": 11.5,
#                 "uv": 1.0
#             },
#             {
#                 "time_epoch": 1686794400,
#                 "time": "2023-06-14 22:00",
#                 "temp_c": 28.8,
#                 "temp_f": 83.8,
#                 "is_day": 0,
#                 "condition": {
#                     "text": "Partly cloudy",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/night/116.png",
#                     "code": 1003
#                 },
#                 "wind_mph": 5.8,
#                 "wind_kph": 9.4,
#                 "wind_degree": 141,
#                 "wind_dir": "SE",
#                 "pressure_mb": 1015.0,
#                 "pressure_in": 29.97,
#                 "precip_mm": 0.0,
#                 "precip_in": 0.0,
#                 "humidity": 70,
#                 "cloud": 31,
#                 "feelslike_c": 32.4,
#                 "feelslike_f": 90.3,
#                 "windchill_c": 28.8,
#                 "windchill_f": 83.8,
#                 "heatindex_c": 32.4,
#                 "heatindex_f": 90.3,
#                 "dewpoint_c": 22.8,
#                 "dewpoint_f": 73.0,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 0,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 7.6,
#                 "gust_kph": 12.2,
#                 "uv": 1.0
#             },
#             {
#                 "time_epoch": 1686798000,
#                 "time": "2023-06-14 23:00",
#                 "temp_c": 28.8,
#                 "temp_f": 83.8,
#                 "is_day": 0,
#                 "condition": {
#                     "text": "Clear",
#                     "icon": "//cdn.weatherapi.com/weather/64x64/night/113.png",
#                     "code": 1000
#                 },
#                 "wind_mph": 8.3,
#                 "wind_kph": 13.3,
#                 "wind_degree": 144,
#                 "wind_dir": "SE",
#                 "pressure_mb": 1015.0,
#                 "pressure_in": 29.96,
#                 "precip_mm": 0.0,
#                 "precip_in": 0.0,
#                 "humidity": 71,
#                 "cloud": 10,
#                 "feelslike_c": 32.5,
#                 "feelslike_f": 90.5,
#                 "windchill_c": 28.8,
#                 "windchill_f": 83.8,
#                 "heatindex_c": 32.5,
#                 "heatindex_f": 90.5,
#                 "dewpoint_c": 23.0,
#                 "dewpoint_f": 73.4,
#                 "will_it_rain": 0,
#                 "chance_of_rain": 0,
#                 "will_it_snow": 0,
#                 "chance_of_snow": 0,
#                 "vis_km": 10.0,
#                 "vis_miles": 6.0,
#                 "gust_mph": 10.7,
#                 "gust_kph": 17.3,
#                 "uv": 1.0
#             }
#         ]
#     }
# ]

# %%
hourlytemps = []
for hour in item1:
    for time in hour['hour']:
        hourlyinfo = {}
        hourlyinfo["time"] = time["time"]
        hourlyinfo["temperature_c"] = time["temp_c"]
        hourlytemps.append(hourlyinfo)
print(hourlytemps)
import json
pretty2 = json.dumps(hourlytemps, indent = 4)
print(pretty2)
# Out:
# [{'time': '2023-06-14 00:00', 'temperature_c': 28.5}, {'time': '2023-06-14 01:00', 'temperature_c': 28.5}, {'time': '2023-06-14 02:00', 'temperature_c': 28.1}, {'time': '2023-06-14 03:00', 'temperature_c': 28.3}, {'time': '2023-06-14 04:00', 'temperature_c': 28.2}, {'time': '2023-06-14 05:00', 'temperature_c': 28.1}, {'time': '2023-06-14 06:00', 'temperature_c': 28.1}, {'time': '2023-06-14 07:00', 'temperature_c': 28.3}, {'time': '2023-06-14 08:00', 'temperature_c': 28.7}, {'time': '2023-06-14 09:00', 'temperature_c': 29.2}, {'time': '2023-06-14 10:00', 'temperature_c': 29.6}, {'time': '2023-06-14 11:00', 'temperature_c': 30.3}, {'time': '2023-06-14 12:00', 'temperature_c': 31.2}, {'time': '2023-06-14 13:00', 'temperature_c': 33.7}, {'time': '2023-06-14 14:00', 'temperature_c': 33.9}, {'time': '2023-06-14 15:00', 'temperature_c': 34.1}, {'time': '2023-06-14 16:00', 'temperature_c': 34.0}, {'time': '2023-06-14 17:00', 'temperature_c': 33.4}, {'time': '2023-06-14 18:00', 'temperature_c': 32.3}, {'time': '2023-06-14 19:00', 'temperature_c': 30.0}, {'time': '2023-06-14 20:00', 'temperature_c': 28.9}, {'time': '2023-06-14 21:00', 'temperature_c': 28.8}, {'time': '2023-06-14 22:00', 'temperature_c': 28.8}, {'time': '2023-06-14 23:00', 'temperature_c': 28.8}]
# [
#     {
#         "time": "2023-06-14 00:00",
#         "temperature_c": 28.5
#     },
#     {
#         "time": "2023-06-14 01:00",
#         "temperature_c": 28.5
#     },
#     {
#         "time": "2023-06-14 02:00",
#         "temperature_c": 28.1
#     },
#     {
#         "time": "2023-06-14 03:00",
#         "temperature_c": 28.3
#     },
#     {
#         "time": "2023-06-14 04:00",
#         "temperature_c": 28.2
#     },
#     {
#         "time": "2023-06-14 05:00",
#         "temperature_c": 28.1
#     },
#     {
#         "time": "2023-06-14 06:00",
#         "temperature_c": 28.1
#     },
#     {
#         "time": "2023-06-14 07:00",
#         "temperature_c": 28.3
#     },
#     {
#         "time": "2023-06-14 08:00",
#         "temperature_c": 28.7
#     },
#     {
#         "time": "2023-06-14 09:00",
#         "temperature_c": 29.2
#     },
#     {
#         "time": "2023-06-14 10:00",
#         "temperature_c": 29.6
#     },
#     {
#         "time": "2023-06-14 11:00",
#         "temperature_c": 30.3
#     },
#     {
#         "time": "2023-06-14 12:00",
#         "temperature_c": 31.2
#     },
#     {
#         "time": "2023-06-14 13:00",
#         "temperature_c": 33.7
#     },
#     {
#         "time": "2023-06-14 14:00",
#         "temperature_c": 33.9
#     },
#     {
#         "time": "2023-06-14 15:00",
#         "temperature_c": 34.1
#     },
#     {
#         "time": "2023-06-14 16:00",
#         "temperature_c": 34.0
#     },
#     {
#         "time": "2023-06-14 17:00",
#         "temperature_c": 33.4
#     },
#     {
#         "time": "2023-06-14 18:00",
#         "temperature_c": 32.3
#     },
#     {
#         "time": "2023-06-14 19:00",
#         "temperature_c": 30.0
#     },
#     {
#         "time": "2023-06-14 20:00",
#         "temperature_c": 28.9
#     },
#     {
#         "time": "2023-06-14 21:00",
#         "temperature_c": 28.8
#     },
#     {
#         "time": "2023-06-14 22:00",
#         "temperature_c": 28.8
#     },
#     {
#         "time": "2023-06-14 23:00",
#         "temperature_c": 28.8
#     }
# ]

# %%
for hour in item1:
  for time in hour['hour']:
    print(time["time"])
    if time["cloud"] > 50:
      print(time["temp_c"], "and cloudy")
    else:
      print(time["temp_c"])
# Out:
# 2023-06-14 00:00
# 28.5 and cloudy
# 2023-06-14 01:00
# 28.5 and cloudy
# 2023-06-14 02:00
# 28.1 and cloudy
# 2023-06-14 03:00
# 28.3 and cloudy
# 2023-06-14 04:00
# 28.2 and cloudy
# 2023-06-14 05:00
# 28.1 and cloudy
# 2023-06-14 06:00
# 28.1
# 2023-06-14 07:00
# 28.3
# 2023-06-14 08:00
# 28.7 and cloudy
# 2023-06-14 09:00
# 29.2
# 2023-06-14 10:00
# 29.6
# 2023-06-14 11:00
# 30.3
# 2023-06-14 12:00
# 31.2
# 2023-06-14 13:00
# 33.7
# 2023-06-14 14:00
# 33.9
# 2023-06-14 15:00
# 34.1
# 2023-06-14 16:00
# 34.0
# 2023-06-14 17:00
# 33.4
# 2023-06-14 18:00
# 32.3
# 2023-06-14 19:00
# 30.0 and cloudy
# 2023-06-14 20:00
# 28.9 and cloudy
# 2023-06-14 21:00
# 28.8
# 2023-06-14 22:00
# 28.8
# 2023-06-14 23:00
# 28.8

# %% [markdown]
# ## 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
url = f"http://api.weatherapi.com/v1/forecast.json?key={api_key}&q=Miami, Florida&days=1&aqi=no&alerts=no"
response = requests.get(url)
data = response.json()

# %%
miami24 = []
for hour in item1:
  for time in hour['hour']:
    if time["temp_f"] > 85:
      above85 = time["temp_f"]
      miami24.append(above85)
# The number of hours in the day where the temp is above 85.
totalhours = len(miami24)
above85_percent = totalhours * 100 / 24
print(round(above85_percent, 2))
# Out:
# 41.67

# %% [markdown]
# ## 9) How much will it cost if you need to use 1,500,000 API calls?
#
# You are only allowed 1,000,000 API calls each month. If you were really bad at this homework or made some awful loops, WeatherAPI might shut down your free access.
#
# * *Tip: this involves looking somewhere that isn't the normal documentation.*

# %%
# The cost is USD 4 per month.
# Source: https://www.weatherapi.com/pricing.aspx

# %% [markdown]
# ## 10) You're too poor to spend more money! What else could you do instead of give them money?
#
# * *Tip: I'm not endorsing being sneaky, but newsrooms and students are both generally poverty-stricken.*

# %%
# Create different accounts (different APIs). We can create a list of APIs so it iterates, one to the other, before the limit.
